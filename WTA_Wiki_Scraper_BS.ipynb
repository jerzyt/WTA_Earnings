# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/Iga_Swiatek'

# %%
html = urlopen(url)
bs = BeautifulSoup(html.read(), 'html.parser')

# %%
table = bs.find('table', {'class': 'infobox vcard'})
for tr in table.find_all('tr'):
    print(tr)
    print('>>> TEXT >>>' + tr.get_text() + '<<< END TEXT <<<')
# Out:
# <tr><td class="infobox-image" colspan="2"><a class="image" href="/wiki/File:Swiatek_RG19_(1)_(48199020336).jpg"><img alt="Swiatek RG19 (1) (48199020336).jpg" data-file-height="3413" data-file-width="2275" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Swiatek_RG19_%281%29_%2848199020336%29.jpg/220px-Swiatek_RG19_%281%29_%2848199020336%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Swiatek_RG19_%281%29_%2848199020336%29.jpg/330px-Swiatek_RG19_%281%29_%2848199020336%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Swiatek_RG19_%281%29_%2848199020336%29.jpg/440px-Swiatek_RG19_%281%29_%2848199020336%29.jpg 2x" width="220"/></a><div class="infobox-caption">Świątek at the <a href="/wiki/2019_French_Open" title="2019 French Open">2019 French Open</a></div></td></tr>
# >>> TEXT >>>Świątek at the 2019 French Open<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Country (sports)</th><td class="infobox-data"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="800" data-file-width="1280" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/en/thumb/1/12/Flag_of_Poland.svg/23px-Flag_of_Poland.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/12/Flag_of_Poland.svg/35px-Flag_of_Poland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/12/Flag_of_Poland.svg/46px-Flag_of_Poland.svg.png 2x" width="23"/> </span><a href="/wiki/Poland" title="Poland">Poland</a></td></tr>
# >>> TEXT >>>Country (sports) Poland<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Residence</th><td class="infobox-data label"><a href="/wiki/Raszyn" title="Raszyn">Raszyn</a>, Poland</td></tr>
# >>> TEXT >>>ResidenceRaszyn, Poland<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><span style="display:none"> (<span class="bday">2001-05-31</span>) </span>31 May 2001<span class="noprint ForceAgeToShow"> (age 21)</span><br/><a href="/wiki/Warsaw" title="Warsaw">Warsaw</a>, Poland</td></tr>
# >>> TEXT >>>Born (2001-05-31) 31 May 2001 (age 21)Warsaw, Poland<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Height</th><td class="infobox-data">1.76 m (5 ft 9 in)</td></tr>
# >>> TEXT >>>Height1.76 m (5 ft 9 in)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Turned pro</th><td class="infobox-data">October 2016</td></tr>
# >>> TEXT >>>Turned proOctober 2016<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Plays</th><td class="infobox-data">Right-handed (two-handed backhand)</td></tr>
# >>> TEXT >>>PlaysRight-handed (two-handed backhand)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Coach</th><td class="infobox-data">Tomasz Wiktorowski</td></tr>
# >>> TEXT >>>CoachTomasz Wiktorowski<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Prize money</th><td class="infobox-data">US$ 14,735,077 <sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>
# <ul><li><a href="/wiki/WTA_Tour_records#WTA_career_prize_money_leaders" title="WTA Tour records">34th in all-time rankings</a></li></ul>
# </td></tr>
# >>> TEXT >>>Prize moneyUS$ 14,735,077 [1]
# 34th in all-time rankings
# <<< END TEXT <<<
# <tr><th class="infobox-header" colspan="2" style="background-color:lavender;">Singles</th></tr>
# >>> TEXT >>>Singles<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Career record</th><td class="infobox-data">213–55 (79.5%)</td></tr>
# >>> TEXT >>>Career record213–55 (79.5%)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Career titles</th><td class="infobox-data">11</td></tr>
# >>> TEXT >>>Career titles11<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Highest ranking</th><td class="infobox-data"><a href="/wiki/List_of_WTA_number_1_ranked_singles_tennis_players" title="List of WTA number 1 ranked singles tennis players">No. <b>1</b></a> (4 April 2022)</td></tr>
# >>> TEXT >>>Highest rankingNo. 1 (4 April 2022)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Current ranking</th><td class="infobox-data">No. <b>1</b> (4 April 2022)</td></tr>
# >>> TEXT >>>Current rankingNo. 1 (4 April 2022)<<< END TEXT <<<
# <tr><th class="infobox-header" colspan="2" style="background-color:lavender;">Grand Slam singles results</th></tr>
# >>> TEXT >>>Grand Slam singles results<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row"><a href="/wiki/Australian_Open" title="Australian Open">Australian Open</a></th><td class="infobox-data">SF (<a href="/wiki/2022_Australian_Open_%E2%80%93_Women%27s_singles" title="2022 Australian Open – Women's singles">2022</a>)</td></tr>
# >>> TEXT >>>Australian OpenSF (2022)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row"><a href="/wiki/French_Open" title="French Open">French Open</a></th><td class="infobox-data"><b>W</b> (<a href="/wiki/2020_French_Open_%E2%80%93_Women%27s_singles" title="2020 French Open – Women's singles">2020</a>, <a href="/wiki/2022_French_Open_%E2%80%93_Women%27s_singles" title="2022 French Open – Women's singles">2022</a>)</td></tr>
# >>> TEXT >>>French OpenW (2020, 2022)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row"><a href="/wiki/Wimbledon_Championships" title="Wimbledon Championships">Wimbledon</a></th><td class="infobox-data">4R (<a href="/wiki/2021_Wimbledon_Championships_%E2%80%93_Women%27s_singles" title="2021 Wimbledon Championships – Women's singles">2021</a>)</td></tr>
# >>> TEXT >>>Wimbledon4R (2021)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row"><a href="/wiki/US_Open_(tennis)" title="US Open (tennis)">US Open</a></th><td class="infobox-data"><b>W</b> (<a href="/wiki/2022_US_Open_%E2%80%93_Women%27s_singles" title="2022 US Open – Women's singles">2022</a>)</td></tr>
# >>> TEXT >>>US OpenW (2022)<<< END TEXT <<<
# <tr><th class="infobox-header" colspan="2" style="background-color:lavender;">Other tournaments</th></tr>
# >>> TEXT >>>Other tournaments<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row"><a href="/wiki/WTA_Finals" title="WTA Finals">Tour Finals</a></th><td class="infobox-data">SF (<a href="/wiki/2022_WTA_Finals_%E2%80%93_Singles" title="2022 WTA Finals – Singles">2022</a>)</td></tr>
# >>> TEXT >>>Tour FinalsSF (2022)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row"><a href="/wiki/Tennis_at_the_Summer_Olympics" title="Tennis at the Summer Olympics">Olympic Games</a></th><td class="infobox-data">2R (<a href="/wiki/Tennis_at_the_2020_Summer_Olympics_%E2%80%93_Women%27s_singles" title="Tennis at the 2020 Summer Olympics – Women's singles">2021</a>)</td></tr>
# >>> TEXT >>>Olympic Games2R (2021)<<< END TEXT <<<
# <tr><th class="infobox-header" colspan="2" style="background-color:lavender;">Doubles</th></tr>
# >>> TEXT >>>Doubles<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Career record</th><td class="infobox-data">27–14 (65.9%)</td></tr>
# >>> TEXT >>>Career record27–14 (65.9%)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Career titles</th><td class="infobox-data">0</td></tr>
# >>> TEXT >>>Career titles0<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Highest ranking</th><td class="infobox-data">No. 29 (14 February 2022)</td></tr>
# >>> TEXT >>>Highest rankingNo. 29 (14 February 2022)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Current ranking</th><td class="infobox-data">No. 506 (26 September 2022)</td></tr>
# >>> TEXT >>>Current rankingNo. 506 (26 September 2022)<<< END TEXT <<<
# <tr><th class="infobox-header" colspan="2" style="background-color:lavender;">Grand Slam doubles results</th></tr>
# >>> TEXT >>>Grand Slam doubles results<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row"><a href="/wiki/French_Open" title="French Open">French Open</a></th><td class="infobox-data">F (<a href="/wiki/2021_French_Open_%E2%80%93_Women%27s_doubles" title="2021 French Open – Women's doubles">2021</a>)</td></tr>
# >>> TEXT >>>French OpenF (2021)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row"><a href="/wiki/US_Open_(tennis)" title="US Open (tennis)">US Open</a></th><td class="infobox-data">2R (<a href="/wiki/2019_US_Open_%E2%80%93_Women%27s_doubles" title="2019 US Open – Women's doubles">2019</a>)</td></tr>
# >>> TEXT >>>US Open2R (2019)<<< END TEXT <<<
# <tr><th class="infobox-header" colspan="2" style="background-color:lavender;">Mixed doubles</th></tr>
# >>> TEXT >>>Mixed doubles<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Career record</th><td class="infobox-data note">5–4 (55.6%)</td></tr>
# >>> TEXT >>>Career record5–4 (55.6%)<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row">Career titles</th><td class="infobox-data note">0</td></tr>
# >>> TEXT >>>Career titles0<<< END TEXT <<<
# <tr><th class="infobox-header" colspan="2" style="background-color:lavender;">Grand Slam mixed doubles results</th></tr>
# >>> TEXT >>>Grand Slam mixed doubles results<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row"><a href="/wiki/Australian_Open" title="Australian Open">Australian Open</a></th><td class="infobox-data">QF (<a href="/wiki/2020_Australian_Open_%E2%80%93_Mixed_doubles" title="2020 Australian Open – Mixed doubles">2020</a>)</td></tr>
# >>> TEXT >>>Australian OpenQF (2020)<<< END TEXT <<<
# <tr><th class="infobox-header" colspan="2" style="background-color:lavender;">Other mixed doubles tournaments</th></tr>
# >>> TEXT >>>Other mixed doubles tournaments<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row"><a href="/wiki/Tennis_at_the_Summer_Olympics" title="Tennis at the Summer Olympics">Olympic Games</a></th><td class="infobox-data">QF (<a href="/wiki/Tennis_at_the_2020_Summer_Olympics_%E2%80%93_Mixed_doubles" title="Tennis at the 2020 Summer Olympics – Mixed doubles">2020</a>)</td></tr>
# >>> TEXT >>>Olympic GamesQF (2020)<<< END TEXT <<<
# <tr><th class="infobox-header" colspan="2" style="background-color:lavender;">Team competitions</th></tr>
# >>> TEXT >>>Team competitions<<< END TEXT <<<
# <tr><th class="infobox-label" scope="row"><a class="mw-redirect" href="/wiki/BJK_Cup" title="BJK Cup">BJK Cup</a></th><td class="infobox-data">Finals (<i><a href="/wiki/2022_Billie_Jean_King_Cup" title="2022 Billie Jean King Cup">2022</a></i>) <br/> record 7–2 (78%)</td></tr>
# >>> TEXT >>>BJK CupFinals (2022)  record 7–2 (78%)<<< END TEXT <<<
# <tr><td class="infobox-full-data" colspan="2"><link href="mw-data:TemplateStyles:r1066479718" rel="mw-deduplicated-inline-style"/></td></tr>
# >>> TEXT >>><<< END TEXT <<<
# <tr><th class="infobox-header" colspan="2">Signature</th></tr>
# >>> TEXT >>>Signature<<< END TEXT <<<
# <tr><td class="infobox-full-data" colspan="2"><a class="image" href="/wiki/File:IgaSwiatekSignature.png"><img alt="IgaSwiatekSignature.png" data-file-height="194" data-file-width="385" decoding="async" height="76" src="//upload.wikimedia.org/wikipedia/en/thumb/2/24/IgaSwiatekSignature.png/150px-IgaSwiatekSignature.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/2/24/IgaSwiatekSignature.png/225px-IgaSwiatekSignature.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/2/24/IgaSwiatekSignature.png/300px-IgaSwiatekSignature.png 2x" width="150"/></a></td></tr>
# >>> TEXT >>><<< END TEXT <<<
# <tr style="display:none"><td colspan="2">
# </td></tr>
# >>> TEXT >>>
# <<< END TEXT <<<
# <tr><th class="infobox-header" colspan="2" style="background-color:lavender;"><div class="mw-collapsible" style="text-align:center; font-size:95%">
# <div style="line-height:1.6em; font-weight:bold; background-color:#ccf; font-size:105%; background-color:transparent;"><div style="margin:0 4em;">Medal record</div></div>
# <div class="mw-collapsible-content" style="font-size:105%;">
# <table style="width:100%; background-color:#f9f9f9; color:#000000; font-weight:normal;">
# <tbody><tr>
# <td>
# </td></tr>
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#eeeeee;">Women's <a href="/wiki/Tennis" title="Tennis">tennis</a>
# </th></tr>
# <tr>
# <th class="adr" colspan="3" style="text-align:center;vertical-align:middle;background-color:#eeeeee;">Representing <span class="country-name"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Olympic_flag.svg/22px-Olympic_flag.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Olympic_flag.svg/33px-Olympic_flag.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Olympic_flag.svg/44px-Olympic_flag.svg.png 2x" width="22"/> <a href="/wiki/Mixed-NOCs_at_the_Youth_Olympics" title="Mixed-NOCs at the Youth Olympics">Mixed-NOCs</a> <span style="font-size:90%;">(MIX)</span></span>
# </th></tr>
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#cccccc;"><a class="mw-redirect" href="/wiki/Summer_Youth_Olympics" title="Summer Youth Olympics">Summer Youth Olympics</a>
# </th></tr>
# <tr>
# <td style="text-align:center;vertical-align:middle;"><img alt="Gold medal – first place" data-file-height="16" data-file-width="16" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/16px-Gold_medal_icon_%28G_initial%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/24px-Gold_medal_icon_%28G_initial%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/32px-Gold_medal_icon_%28G_initial%29.svg.png 2x" title="Gold medal – first place" width="16"/></td>
# <td style="text-align:center;vertical-align:middle;"><span class="nowrap"><a href="/wiki/Tennis_at_the_2018_Summer_Youth_Olympics" title="Tennis at the 2018 Summer Youth Olympics">2018 Buenos Aires</a></span></td>
# <td style="text-align:center;vertical-align:middle;">Doubles
# </td></tr></tbody></table>
# </div></div></th></tr>
# >>> TEXT >>>
# Medal record
#
#
#
#
#
#
# Women's tennis
#
#
# Representing  Mixed-NOCs (MIX)
#
#
# Summer Youth Olympics
#
#
#
# 2018 Buenos Aires
# Doubles
#
# <<< END TEXT <<<
# <tr>
# <td>
# </td></tr>
# >>> TEXT >>>
#
# <<< END TEXT <<<
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#eeeeee;">Women's <a href="/wiki/Tennis" title="Tennis">tennis</a>
# </th></tr>
# >>> TEXT >>>
# Women's tennis
# <<< END TEXT <<<
# <tr>
# <th class="adr" colspan="3" style="text-align:center;vertical-align:middle;background-color:#eeeeee;">Representing <span class="country-name"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Olympic_flag.svg/22px-Olympic_flag.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Olympic_flag.svg/33px-Olympic_flag.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Olympic_flag.svg/44px-Olympic_flag.svg.png 2x" width="22"/> <a href="/wiki/Mixed-NOCs_at_the_Youth_Olympics" title="Mixed-NOCs at the Youth Olympics">Mixed-NOCs</a> <span style="font-size:90%;">(MIX)</span></span>
# </th></tr>
# >>> TEXT >>>
# Representing  Mixed-NOCs (MIX)
# <<< END TEXT <<<
# <tr>
# <th colspan="3" style="text-align:center;vertical-align:middle;background-color:#cccccc;"><a class="mw-redirect" href="/wiki/Summer_Youth_Olympics" title="Summer Youth Olympics">Summer Youth Olympics</a>
# </th></tr>
# >>> TEXT >>>
# Summer Youth Olympics
# <<< END TEXT <<<
# <tr>
# <td style="text-align:center;vertical-align:middle;"><img alt="Gold medal – first place" data-file-height="16" data-file-width="16" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/16px-Gold_medal_icon_%28G_initial%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/24px-Gold_medal_icon_%28G_initial%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Gold_medal_icon_%28G_initial%29.svg/32px-Gold_medal_icon_%28G_initial%29.svg.png 2x" title="Gold medal – first place" width="16"/></td>
# <td style="text-align:center;vertical-align:middle;"><span class="nowrap"><a href="/wiki/Tennis_at_the_2018_Summer_Youth_Olympics" title="Tennis at the 2018 Summer Youth Olympics">2018 Buenos Aires</a></span></td>
# <td style="text-align:center;vertical-align:middle;">Doubles
# </td></tr>
# >>> TEXT >>>
#
# 2018 Buenos Aires
# Doubles
# <<< END TEXT <<<
# <tr><td class="infobox-below" colspan="2" style="font-weight: lighter; color: #555">Last updated on: 7 November 2022.</td></tr>
# >>> TEXT >>>Last updated on: 7 November 2022.<<< END TEXT <<<
